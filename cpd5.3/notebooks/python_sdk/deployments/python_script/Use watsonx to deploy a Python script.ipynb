# %% [markdown]
# # Use `ibm-watsonx-ai` to deploy a Python script
# This notebook contains steps and code to demonstrate how to deploy a Python script with the [ibm-watsonx-ai](https://pypi.python.org/pypi/ibm-watsonx-ai) library available in the PyPI repository. This notebook consists of steps to create a Python script, create a deployment, create and run a job.
#
# Some familiarity with Python is helpful. This notebook uses Python 3.12.

# %% [markdown]
# ## Learning goals
# The learning goals of this notebook are:
#
# - Create and save a python script.
# - Deploy the script using the client library.
# - Create and Run a job which utilizes the created deployment.
#
# ## Contents
# This notebook contains the following parts:
#
# 1. [Setup](#section1)
# 2. [Deployment of Python Script](#section2)
# 3. [Create and Run Job](#section3)
# 4. [Clean up](#section4)
# 5. [Summary](#section5)

# %% [markdown]
# <a id='section1'></a>
# ## 1. Set up the environment
#
# Before you use the sample code in this notebook, you must perform the following setup tasks:
#
# -  Contact your IBM Cloud Pak® for Data administrator and ask them for your account credentials

# %% [markdown]
# ### Install dependencies
# **Note:** `ibm-watsonx-ai` documentation can be found <a href="https://ibm.github.io/watsonx-ai-python-sdk/index.html" target="_blank" rel="noopener no referrer">here</a>.

# %%
# %pip install -U ibm-watsonx-ai | tail -n 1
# Out:
# Successfully installed ibm-watsonx-ai-1.4.7
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Define credentials
#
# Authenticate the watsonx.ai Runtime service on IBM Cloud Pak® for Data. You need to provide the **admin's** `username` and the platform `url`.

# %%
username = "PASTE YOUR USERNAME HERE"
url = "PASTE THE PLATFORM URL HERE"

# %% [markdown]
# Use the **admin's** `api_key` to authenticate watsonx.ai Runtime services:

# %%
import getpass

from ibm_watsonx_ai import Credentials

credentials = Credentials(
    username=username,
    api_key=getpass.getpass("Enter your watsonx.ai API key and hit enter: "),
    url=url,
    instance_id="openshift",
    version="5.3",
)

# %% [markdown]
# Alternatively you can use the **admin's** `password`:

# %%
import getpass

from ibm_watsonx_ai import Credentials

if "credentials" not in locals() or not credentials.api_key:
    credentials = Credentials(
        username=username,
        password=getpass.getpass("Enter your watsonx.ai password and hit enter: "),
        url=url,
        instance_id="openshift",
        version="5.3",
    )
# Out:
# Enter your watsonx.ai password and hit enter:  ········

# %% [markdown]
# #### Create `APIClient` instance

# %%
from ibm_watsonx_ai import APIClient

client = APIClient(credentials)

# %% [markdown]
# ### Working with spaces
#
# First of all, you need to create a space that will be used for your work. If you do not have space already created, you can use `{PLATFORM_URL}/ml-runtime/spaces?context=icp4data` to create one.
#
# - Click New Deployment Space
# - Create an empty space
# - Go to space `Settings` tab
# - Copy `space_id` and paste it below
#
# **Tip**: You can also use SDK to prepare the space for your work. More information can be found [here](https://github.com/IBM/watsonx-ai-samples/blob/master/cpd5.3/notebooks/python_sdk/instance-management/Space%20management.ipynb).
#
# **Action**: Assign space ID below

# %%
space_id = "PASTE YOUR SPACE ID HERE"

# %% [markdown]
# You can use `list` method to print all existing spaces.

# %%
client.spaces.list(limit=10)

# %% [markdown]
# To be able to interact with all resources available in Watson Machine Learning, you need to set **space** which you will be using.

# %%
client.set.default_space(space_id)
# Out:
# 'SUCCESS'

# %% [markdown]
# ### Software specification
#
# You can use popular tools, libraries, and frameworks to train and deploy machine learning models and functions.
#
# The following list shows the predefined (base) model types and software specifications.

# %%
client.software_specifications.list()
# Out:
#                                NAME                                    ID  \
# 0           autoai-kb_rt25.1-py3.12  046f5252-0d07-5c23-81ef-18a1a31cdce3
# 1      tensorflow_rt25.1-py3.12-edt  0747503b-cc2e-5249-9019-59df39a112b8
# 2            watsonx-textgen-fm-1.0  129aec82-7e65-5c78-b812-4c0a74b916f5
# 3               masking-flows-spark  13666829-5570-53a7-927b-52d42a101d93
# 4           autoai-ts_rt25.1-py3.12  1c0c9e1d-8523-520f-867e-102173f16f5e
# 5                 runtime-25.1-r4.4  2b2ddb1d-6c0f-5b95-9d04-3056270ea5c6
# 6          tensorflow_rt24.1-py3.11  2c33167d-b11c-5490-a305-3e5e95db5c4d
# 7        pytorch-onnx_rt24.1-py3.11  2da185aa-eac3-59a5-bb8e-0e5b60458a15
# 8      tensorflow_rt24.1-py3.11-edt  2f53b747-c01a-58a6-a20c-8390ecfd8625
# 9            kernel-spark3.5-py3.11  30ad99e2-7cfb-511a-9a3e-4cc308071fd3
# 10         runtime-25.1-py3.12-cuda  347e3aa2-a7f2-519c-a444-ade0e3433b74
# 11             kernel-spark3.5-r4.3  3668b4d5-b8b8-5926-badf-1134137613d4
# 12             onnxruntime_opset_19  368d2795-aaa7-59a0-834c-248c64a5a99e
# 13                rstudio-24.1-r4.3  3f54a6c2-0df5-58db-8121-ca947a0691d0
# 14       pytorch-onnx_rt25.1-py3.12  4405592f-9ff7-5497-8171-18bbc5c2543a
# 15              runtime-24.1-py3.11  45f12dfe-aa78-5b8d-9f38-0ee223c47309
# 16           kernel-spark3.4-py3.11  47c18b7b-f719-5f8c-ad84-a1a64a174204
# 17                     pmml-3.0_4.3  493bcb95-16f1-5bc5-bee8-81b8af80e9c7
# 18  pytorch-onnx_rt25.1-py3.12-dist  4a43630d-c29d-5360-af55-06b2dd88eb1d
# 19           kernel-spark4.0-py3.11  4f205e31-5c21-5b78-9ba3-41337452de83
# 20    tensorflow_rt24.1-py3.11-dist  5664b780-493c-59db-a165-c57ad6417db7
# 21                spss-modeler_18.1  5c3cad7e-507f-4b2a-a9a3-ab53a21dee8b
# 22          wx_data-spark3.5-py3.11  63e7aeea-51bd-5638-b645-db93f2deb1c7
# 23                spss-modeler_18.2  687eddc9-028a-4117-b9dd-e57b36f1efa5
# 24           watsonx-cfm-caikit-1.1  69fcc3e0-48de-5ef5-8682-53e86781d1a6
# 25         tensorflow_rt25.1-py3.12  6fe02459-33b6-5b56-bc6d-84a3ff6d4694
# 26                rstudio-25.1-r4.4  75de0dd4-ff77-51dd-9716-834b0671bb37
# 27          wx_data-spark3.4-py3.10  76615114-0e24-5e14-ac71-5aa197d82062
# 28          autoai-ts_rt24.1-py3.11  7d222e1d-b062-5740-b34a-453a63755976
# 29          autoai-kb_rt24.1-py3.11  82f1bc6d-59c3-55e8-b612-cd908a2f7cc7
# 30                       hybrid_0.1  8c1a58c6-62b5-4dc4-987a-df751c2756b6
# 31                spss-modeler_17.1  902d0051-84bd-4af6-ab6b-8f6aa6fdeabb
# 32                       hybrid_0.2  9b3f9040-9cee-4ead-8d7a-780600f542f7
# 33             kernel-spark3.4-r4.3  a3ce4e69-29af-536d-9c5b-e8142fbd2629
# 34             kernel-spark4.0-r4.3  ab83bf93-80c0-5d32-a18f-7f79584520a3
# 35          wx_data-spark4.0-py3.11  ab891c12-4073-531f-8872-4378da3ecd43
# 36         runtime-24.1-py3.11-cuda  b5993284-af60-57ff-aaf2-e0989be7ca2d
# 37                runtime-24.1-r4.3  c9679e95-1b5e-590d-a6ce-0c15dc870a0a
# 38         watsonx-tsfm-runtime-1.0  cc8d3794-43e5-5bcf-a657-9cfed2f278c4
# 39                  spark-mllib_3.4  dabb5e1b-e1c7-5ef5-95ea-34a8223e436c
# 40           watsonx-er-runtime-1.0  e226c9c5-eeae-5b66-89fb-aa6f60acd20a
# 41                          do_22.1  e51999ba-6452-5f1f-8287-17228b88b652
# 42                  spark-mllib_3.5  e8cd7001-fd05-5eea-b697-0a3bff9cf51f
# 43         autoai-rag_rt24.1-py3.11  ec4289a9-174e-5eae-ae49-30fa015ed1e6
# 44   pytorch-onnx_rt25.1-py3.12-edt  ed025e22-9239-50af-bddf-5f01a3446a35
# 45   pytorch-onnx_rt24.1-py3.11-edt  ed4d5b3c-faaf-5739-a8d3-ec5cffbc5f13
# 46  pytorch-onnx_rt24.1-py3.11-dist  f0ad08b8-3326-59aa-ba41-ca6694a4e6bc
# 47              runtime-25.1-py3.12  f47ae1c3-198e-5718-b59d-2ea471561e9e
# 48    tensorflow_rt25.1-py3.12-dist  f5885140-e116-5162-80ea-b7a1fb7c66da
# 49                          do_20.1  f686cdd9-7904-5f9d-a732-01b0d6b10dc5
# 50                   linalgnorm-0.1  17f938e7-6b98-44db-b6ca-110b760c2205
# 51        statsmodels software_spec  78f46fe3-81f0-4ab9-a4b8-351694cb9652
#
#        TYPE      STATE REPLACEMENT
# 0      base  supported
# 1      base  supported
# 2      base  supported
# 3      base  supported
# 4      base  supported
# 5      base  supported
# 6      base  supported
# 7      base  supported
# 8      base  supported
# 9      base  supported
# 10     base  supported
# 11     base  supported
# 12     base  supported
# 13     base  supported
# 14     base  supported
# 15     base  supported
# 16     base  supported
# 17     base  supported
# 18     base  supported
# 19     base  supported
# 20     base  supported
# 21     base  supported
# 22     base  supported
# 23     base  supported
# 24     base  supported
# 25     base  supported
# 26     base  supported
# 27     base  supported
# 28     base  supported
# 29     base  supported
# 30     base  supported
# 31     base  supported
# 32     base  supported
# 33     base  supported
# 34     base  supported
# 35     base  supported
# 36     base  supported
# 37     base  supported
# 38     base  supported
# 39     base  supported
# 40     base  supported
# 41     base  supported
# 42     base  supported
# 43     base  supported
# 44     base  supported
# 45     base  supported
# 46     base  supported
# 47     base  supported
# 48     base  supported
# 49     base  supported
# 50  derived
# 51  derived

# %% [markdown]
# You can select the software specification using the function below.

# %%
base_sw_spec_id = client.software_specifications.get_uid_by_name("runtime-25.1-py3.12")
print(base_sw_spec_id)
# Out:
# f47ae1c3-198e-5718-b59d-2ea471561e9e

# %% [markdown]
# <a id='section2'></a>
# ## 2. Python Script Deployment

# %% [markdown]
# ### Save Python Script
#
# This file will be saved locally so you can deploy and run it later.

# %%
# %%writefile /tmp/CreateSwSpec_script.py

import sys
import time
import os

outfname = os.path.join(os.environ.get("BATCH_OUTPUT_DIR"), "swspec.log")
with open(outfname, "w") as file:
    try:
        file.write("The deployed python script was run successfully!")
    except Exception as exc:
        file.write(f"The deployed python script failed: {exc}")
        file.write("sys path:")
        file.write(sys.path)
# Out:
# Writing /tmp/CreateSwSpec_script.py

# %% [markdown]
# The file should be successfully created.
# To check its content, you can use the command below.

# %%
# %cat /tmp/CreateSwSpec_script.py
# Out:
# import sys
# import time
# import os
#
# outfname = os.path.join(os.environ.get("BATCH_OUTPUT_DIR"), "swspec.log")
# with open(outfname, "w") as file:
#     try:
#         file.write("The deployed python script was run successfully!")
#     except Exception as exc:
#         file.write(f"The deployed python script failed: {exc}")
#         file.write("sys path:")
#         file.write(sys.path)

# %% [markdown]
# ### Deployment of Python Script
#
# You can store and deploy a Python script and get its details by running the code in following cells.

# %%
meta_props = {
    client.script.ConfigurationMetaNames.NAME: "Python script",
    client.script.ConfigurationMetaNames.SOFTWARE_SPEC_UID: base_sw_spec_id,
}

# %%
script_path = "/tmp/CreateSwSpec_script.py"
script_details = client.script.store(meta_props, file_path=script_path)
script_id = client.script.get_id(script_details)
print("Created script ", script_id)
# Out:
# Creating Script asset...
# SUCCESS
# Created script  157ea401-9138-40a9-8aec-fd77c4e4c482

# %%
script_details
# Out:
# {'metadata': {'name': 'Python script',
#   'guid': '157ea401-9138-40a9-8aec-fd77c4e4c482',
#   'href': '/v2/assets/157ea401-9138-40a9-8aec-fd77c4e4c482?space_id=e4509fba-55db-48c5-94a6-08c399762bf2',
#   'asset_type': 'script',
#   'created_at': '2025-11-19T10:30:46Z',
#   'last_updated_at': '2025-11-19T10:30:46Z',
#   'space_id': 'e4509fba-55db-48c5-94a6-08c399762bf2',
#   'description': ''},
#  'entity': {'script': {'language': {'name': 'python3'},
#    'software_spec': {'base_id': 'f47ae1c3-198e-5718-b59d-2ea471561e9e'}}}}

# %%
deployment_meta_props = {
    client.deployments.ConfigurationMetaNames.NAME: "pyscript_deployment",
    client.deployments.ConfigurationMetaNames.BATCH: {},
    client.deployments.ConfigurationMetaNames.HARDWARE_SPEC: {"name": "S"},
}

deployment_details = client.deployments.create(script_id, deployment_meta_props)
deployment_id = client.deployments.get_id(deployment_details)
# Out:
# ######################################################################################
#
# Synchronous deployment creation for id: '157ea401-9138-40a9-8aec-fd77c4e4c482' started
#
# ######################################################################################
#
#
# ready.
#
#
# -----------------------------------------------------------------------------------------------
# Successfully finished deployment creation, deployment_id='3fae0e95-58f0-4189-a430-f2c8b57497f7'
# -----------------------------------------------------------------------------------------------

# %%
deployment_details
# Out:
# {'entity': {'asset': {'id': '157ea401-9138-40a9-8aec-fd77c4e4c482'},
#   'batch': {},
#   'chat_enabled': False,
#   'custom': {},
#   'deployed_asset_type': 'py_script',
#   'hardware_spec': {'name': 'S', 'num_nodes': 1},
#   'name': 'pyscript_deployment',
#   'space_id': 'e4509fba-55db-48c5-94a6-08c399762bf2',
#   'status': {'state': 'ready'}},
#  'metadata': {'created_at': '2025-11-19T10:30:48.976Z',
#   'id': '3fae0e95-58f0-4189-a430-f2c8b57497f7',
#   'modified_at': '2025-11-19T10:30:48.976Z',
#   'name': 'pyscript_deployment',
#   'owner': '1000331001',
#   'space_id': 'e4509fba-55db-48c5-94a6-08c399762bf2'}}

# %% [markdown]
# <a id='section3'></a>
# ## 3. Create and Run job
#
# Run the following cells to create and run a job with the deployed script.

# %%
import time


def poll_async_job(wml_client, job_uid):
    while True:
        job_status = wml_client.deployments.get_job_status(job_uid)
        print(job_status)
        state = job_status["state"]
        if state == "completed" or "fail" in state:
            return wml_client.deployments.get_job_details(job_uid)
        time.sleep(5)

# %%
job_payload_ref = {
    client.deployments.ScoringMetaNames.OUTPUT_DATA_REFERENCE: {
        "type": "data_asset",
        "location": {"name": "deploy_test_script-out"},
    }
}

job = client.deployments.create_job(deployment_id, meta_props=job_payload_ref)
job_id = client.deployments.get_job_id(job)

# %%
job_details = poll_async_job(client, job_id)
# Out:
# {'completed_at': '', 'running_at': '', 'state': 'queued'}
# {'completed_at': '', 'running_at': '', 'state': 'queued'}
# {'completed_at': '', 'running_at': '', 'state': 'queued'}
# {'completed_at': '', 'running_at': '', 'state': 'queued'}
# {'completed_at': '2025-11-19T10:31:29.820831Z', 'running_at': '2025-11-19T10:31:28.306158Z', 'state': 'completed'}

# %%
client.data_assets.list()
# Out:
#                      NAME  ASSET_TYPE  SIZE  \
# 0  deploy_test_script-out  data_asset    48
#
#                                ASSET_ID
# 0  c6b6aa34-a44e-41cb-a14c-66b30861aa77

# %% [markdown]
# To download the asset run the code below. It will be downloaded as a zip archive.

# %%
scoring_params = client.deployments.get_job_details(job_id)

from ibm_watsonx_ai.helpers import DataConnection

output_data_connection = DataConnection.from_dict(
    scoring_params["entity"]["scoring"]["output_data_reference"]
)
output_data_connection.set_client(client)

output_data_connection.download("/tmp/script_result.txt")

# %%
with open("/tmp/script_result.txt") as file:
    print(file.read())
# Out:
# The deployed python script was run successfully!

# %% [markdown]
# <a id='section4'></a>
# ## 4. Cleanup

# %% [markdown]
# If you want to clean up all created assets:
# - experiments
# - trainings
# - pipelines
# - model definitions
# - models
# - functions
# - deployments
#
# please follow up this sample [notebook](https://github.com/IBM/watsonx-ai-samples/blob/master/cpd5.3/notebooks/python_sdk/instance-management/Machine%20Learning%20artifacts%20management.ipynb).

# %% [markdown]
# <a id='section5'></a>
# ## 5. Summary

# %% [markdown]
# You successfully completed this notebook! You learned how to create and deploy a python script, and create and run a job using Watson Machine Learning.
#
# Check out our _<a href="https://ibm.github.io/watsonx-ai-python-sdk/samples.html" target="_blank" rel="noopener no referrer">Online Documentation</a>_ for more samples, tutorials, documentation, how-tos, and blog posts.

# %% [markdown]
# ### Author
#
# **Jakub Żywiecki**, Software Engineer.
#
# **Rafał Chrzanowski**, Software Engineer Intern at watsonx.ai

# %% [markdown]
# Copyright © 2024-2025 IBM. This notebook and its source code are released under the terms of the MIT License.
