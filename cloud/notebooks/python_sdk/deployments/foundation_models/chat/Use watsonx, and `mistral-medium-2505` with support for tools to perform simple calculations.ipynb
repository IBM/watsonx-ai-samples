# %% [markdown]
# ![image](https://raw.githubusercontent.com/IBM/watson-machine-learning-samples/master/cloud/notebooks/headers/watsonx-Prompt_Lab-Notebook.png)
# # Use watsonx, and `mistralai/mistral-medium-2505` with support for tools to perform simple calculations

# %% [markdown]
# #### Disclaimers
#
# - Use only Projects and Spaces that are available in watsonx context.
#
#
# ## Notebook content
#
# This notebook provides a detailed demonstration of the steps and code required to showcase support for Chat models, including the integration of tools using [LangGraph](https://langchain-ai.github.io/langgraph/) and watsonx.ai models.
#
# Some familiarity with Python is helpful. This notebook uses Python 3.11.
#
#
# ## Learning goal
#
# The purpose of this notebook is to demonstrate how to use Chat models, e.g. `mistralai/mistral-medium-2505` using the tools available in LangGraph. LangGraph is an Agent Orchestrator with which you can build graph applications that automatically execute sequences of actions and in which the LLM is the key decision maker that determines the next step.
#
#
# ## Table of Contents
#
# This notebook contains the following parts:
#
# 1. [Set up the environment](#Set-up-the-environment)
# 2. [Set up a Foundation Model on IBM watsonx.ai](#Set-up-a-Foundation-Model-on-IBM-watsonx.ai)
# 3. [LangChain integration](#LangChain-integration)
# 4. [Example usage](#Example-usage)
# 5. [Summary and next steps](#Summary-and-next-steps)

# %% [markdown]
# <a id="Set-up-the-environment"></a>
# ## Set up the environment
#
# Before you use the sample code in this notebook, you must perform the following setup tasks:
#
# -  Create a <a href="https://cloud.ibm.com/catalog/services/watsonxai-runtime" target="_blank" rel="noopener no referrer">watsonx.ai Runtime Service</a> instance (a free plan is offered and information about how to create the instance can be found <a href="https://dataplatform.cloud.ibm.com/docs/content/wsj/getting-started/wml-plans.html?context=wx&audience=wdp" target="_blank" rel="noopener no referrer">here</a>).

# %% [markdown]
# ### Install dependencies
#
# **Note:** `ibm-watsonx-ai` documentation can be found <a href="https://ibm.github.io/watsonx-ai-python-sdk/index.html" target="_blank" rel="noopener no referrer">here</a>.

# %%
# %pip install -U "langgraph>0.2,<0.3" | tail -n 1
# %pip install -U "langchain_ibm>=0.3,<0.4" | tail -n 1
# Out:
# Successfully installed PyYAML-6.0.3 annotated-types-0.7.0 anyio-4.11.0 certifi-2025.10.5 charset_normalizer-3.4.4 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.11 jsonpatch-1.33 jsonpointer-3.0.0 langchain-core-0.3.79 langgraph-0.2.76 langgraph-checkpoint-2.1.2 langgraph-sdk-0.1.74 langsmith-0.4.38 orjson-3.11.4 ormsgpack-1.11.0 pydantic-2.12.3 pydantic-core-2.41.4 requests-2.32.5 requests-toolbelt-1.0.0 sniffio-1.3.1 tenacity-9.1.2 typing-inspection-0.4.2 urllib3-2.5.0 zstandard-0.25.0
# Successfully installed cachetools-6.2.1 ibm-cos-sdk-2.14.3 ibm-cos-sdk-core-2.14.3 ibm-cos-sdk-s3transfer-2.14.3 ibm-watsonx-ai-1.4.2 jmespath-1.0.1 langchain_ibm-0.3.19 lomond-0.3.3 numpy-2.3.4 pandas-2.2.3 pytz-2025.2 tabulate-0.9.0 tzdata-2025.2

# %% [markdown]
# ### Define the watsonx.ai credentials
# Use the code cell below to define the watsonx.ai credentials that are required to work with watsonx Foundation Model inferencing.
#
# **Action:** Provide the IBM Cloud user API key. For details, see <a href="https://cloud.ibm.com/docs/account?topic=account-userapikey&interface=ui" target="_blank" rel="noopener no referrer">Managing user API keys</a>.

# %%
import getpass

from ibm_watsonx_ai import Credentials

credentials = Credentials(
    url="https://us-south.ml.cloud.ibm.com",
    api_key=getpass.getpass("Enter your watsonx.ai api key and hit enter: "),
)

# %% [markdown]
# ### Define the project ID
# You need to provide the project ID to give the Foundation Model the context for the call. If you have a default project ID set in Watson Studio, the notebook obtains that project ID. Otherwise, you need to provide the project ID in the code cell below.

# %%
import os

try:
    project_id = os.environ["PROJECT_ID"]
except KeyError:
    project_id = input("Enter your project_id and hit enter: ")

# %% [markdown]
# <a id="Set-up-a-Foundation-Model-on-IBM-watsonx.ai"></a>
# ## Set up a Foundation Model on IBM watsonx.ai

# %% [markdown]
# Specify the `model_id` of the model you will use for the chat with tools.

# %%
model_id = "mistralai/mistral-medium-2505"

# %% [markdown]
# <a id="LangChain-integration"></a>
# ## LangChain integration
#
# `ChatWatsonx` is a wrapper around watsonx.ai models that provides chat integration around the models.
#
# ### Initialize the `ChatWatsonx` class

# %%
from langchain_ibm import ChatWatsonx

chat = ChatWatsonx(
    url=credentials.url,  # type: ignore
    apikey=credentials.api_key,  # type: ignore
    model_id=model_id,
    project_id=project_id,
)

# %% [markdown]
# Next, define the assistant's tools to make a calculation.

# %%
from langchain_core.tools import tool


@tool
def add(a: float, b: float) -> float:
    """Add a and b."""
    return a + b


@tool
def subtract(a: float, b: float) -> float:
    """Subtract a and b."""
    return a - b


@tool
def multiply(a: float, b: float) -> float:
    """Multiply a and b."""
    return a * b


@tool
def divide(a: float, b: float) -> float:
    """Divide a and b."""
    return a / b


tools = [add, subtract, multiply, divide]

# %% [markdown]
# Define the graph.

# %%
from langgraph.prebuilt import create_react_agent

graph = create_react_agent(chat, tools=tools)

# %% [markdown]
# Visualize the graph you just created.

# %%
from IPython.display import Image, display

display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# Add a helpful function to print messages from the model.

# %%
def print_stream(stream):
    for s in stream:
        message = s["messages"][-1]
        if isinstance(message, tuple):
            print(message)
        else:
            message.pretty_print()

# %% [markdown]
# <a id="Example-usage"></a>
# ## Example usage
#
# Run the app with an input that needs a tool call.

# %%
inputs = {
    "messages": [("user", "What is the total sum of the numbers 11, 13, and 20?")]
}
print_stream(graph.stream(inputs, stream_mode="values"))
# Out:
# ================================ Human Message =================================
#
# What is the total sum of the numbers 11, 13, and 20?
# ================================== Ai Message ==================================
# Tool Calls:
#   add (MoNulGNl0)
#  Call ID: MoNulGNl0
#   Args:
#     a: 11
#     b: 13
# ================================= Tool Message =================================
# Name: add
#
# 24.0
# ================================== Ai Message ==================================
# Tool Calls:
#   add (U1IIs5nbA)
#  Call ID: U1IIs5nbA
#   Args:
#     a: 24.0
#     b: 20
# ================================= Tool Message =================================
# Name: add
#
# 44.0
# ================================== Ai Message ==================================
#
# The total sum of the numbers 11, 13, and 20 is 44.

# %%
inputs = {"messages": [("user", "What is the result when 81 is subtracted from 100?")]}
print_stream(graph.stream(inputs, stream_mode="values"))
# Out:
# ================================ Human Message =================================
#
# What is the result when 81 is subtracted from 100?
# ================================== Ai Message ==================================
#
# Let's calculate the result when 81 is subtracted from 100.
# Tool Calls:
#   subtract (YNhbvK3Ay)
#  Call ID: YNhbvK3Ay
#   Args:
#     a: 100
#     b: 81
# ================================= Tool Message =================================
# Name: subtract
#
# 19.0
# ================================== Ai Message ==================================
#
# The result when 81 is subtracted from 100 is 19.

# %%
inputs = {"messages": [("user", "Calculate the result of multiplying 10 by 12.")]}
print_stream(graph.stream(inputs, stream_mode="values"))
# Out:
# ================================ Human Message =================================
#
# Calculate the result of multiplying 10 by 12.
# ================================== Ai Message ==================================
#
# To calculate the result of multiplying 10 by 12, I will use the multiplication function.
# Tool Calls:
#   multiply (64szrwa6o)
#  Call ID: 64szrwa6o
#   Args:
#     a: 10
#     b: 12
# ================================= Tool Message =================================
# Name: multiply
#
# 120.0
# ================================== Ai Message ==================================
#
# The result of multiplying 10 by 12 is 120.

# %%
inputs = {"messages": [("user", "Determine the result of dividing 2 by 3.")]}
print_stream(graph.stream(inputs, stream_mode="values"))
# Out:
# ================================ Human Message =================================
#
# Determine the result of dividing 2 by 3.
# ================================== Ai Message ==================================
#
# To determine the result of dividing \( 2 \) by \( 3 \), we can perform the division operation.
#
# Let's calculate \( \frac{2}{3} \).
#
# The result of dividing \( 2 \) by \( 3 \) is approximately \( 0.6667 \).
#
# So, \( \frac{2}{3} = 0.\overline{6} \) or approximately \( 0.6667 \).[TOOL_CALLS]divide{"a": 2, "b": 3}

# %%
inputs = {
    "messages": [
        (
            "user",
            "What is the result when the sum of 2 and 3 is multiplied by 6 and then divided by 10?",
        )
    ]
}
print_stream(graph.stream(inputs, stream_mode="values"))
# Out:
# ================================ Human Message =================================
#
# What is the result when the sum of 2 and 3 is multiplied by 6 and then divided by 10?
# ================================== Ai Message ==================================
#
# To solve the problem step-by-step, I will first add 2 and 3, then multiply the result by 6, and finally divide the result by 10.
#
# 1. **Add 2 and 3**:
#    - 2 + 3 = 5
#
# 2. **Multiply the result by 6**:
#    - 5 * 6 = 30
#
# 3. **Divide the result by 10**:
#    - 30 / 10 = 3
#
# So, the final result is 3.
# Tool Calls:
#   add (mksTOhpie)
#  Call ID: mksTOhpie
#   Args:
#     a: 2
#     b: 3
# ================================= Tool Message =================================
# Name: add
#
# 5.0
# ================================== Ai Message ==================================
#
# multiply{"a": 5, "b": 6}
# Tool Calls:
#   multiply (2QF2LA9us)
#  Call ID: 2QF2LA9us
#   Args:
#     a: 5
#     b: 6
#   divide (QWxazhO2S)
#  Call ID: QWxazhO2S
#   Args:
#     a: 30
#     b: 10
# ================================= Tool Message =================================
# Name: divide
#
# 3.0
# ================================== Ai Message ==================================
#
# The result when the sum of 2 and 3 is multiplied by 6 and then divided by 10 is 3.

# %% [markdown]
# <a id="Summary-and-next-steps"></a>
# ## Summary and next steps
#
# You successfully completed this notebook!
#
# You learned how to build a simple graph using LangGraph and `ChatWatsonx`.
#
# Check out our _<a href="https://ibm.github.io/watsonx-ai-python-sdk/samples.html" target="_blank" rel="noopener no referrer">Online Documentation</a>_ for more samples, tutorials, documentation, how-tos, and blog posts.

# %% [markdown]
# ### Author
#
# **Mateusz Szewczyk**, Software Engineer at watsonx.ai.

# %% [markdown]
# Copyright © 2024-2026 IBM. This notebook and its source code are released under the terms of the MIT License.
