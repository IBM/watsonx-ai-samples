# %% [markdown]
# ![image](https://raw.githubusercontent.com/IBM/watsonx-ai-samples/master/cloud/notebooks/headers/watsonx-Prompt_Lab-Notebook.png)
# # Use watsonx, and `ibm/granite-4-h-small` to make simple chat conversation and tool calls

# %% [markdown]
# #### Disclaimers
#
# - Use only Projects and Spaces that are available in watsonx context.
#
#
# ## Notebook content
#
# This notebook provides a detailed demonstration of the steps and code required to showcase support for Chat models, including the integration of tools and watsonx.ai models.
#
# Some familiarity with Python is helpful. This notebook uses Python 3.12.
#
#
# ## Learning goal
#
# The purpose of this notebook is to demonstrate how to use Chat models, e.g. `ibm/granite-4-h-small` for using tools.
#
#
# ## Table of Contents
#
# This notebook contains the following parts:
#
# - [Setup](#setup)
# - [Foundation Models on watsonx](#models)
# - [Work with chat messages](#chat)
# - [Summary](#summary)

# %% [markdown]
# <a id="setup"></a>
# ## Set up the environment
#
# Before you use the sample code in this notebook, you must perform the following setup tasks:
#
# -  Contact with your IBM Cloud Pak® for Data administrator and ask them for your account credentials

# %% [markdown]
# ### Install dependencies

# %%
# %pip install -U "langchain_ibm>=0.3,<0.4" | tail -n 1
# %pip install -U ibm_watsonx_ai | tail -n 1
# Out:
# Successfully installed PyYAML-6.0.3 annotated-types-0.7.0 anyio-4.12.0 cachetools-6.2.4 certifi-2025.11.12 charset_normalizer-3.4.4 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 ibm-cos-sdk-2.14.3 ibm-cos-sdk-core-2.14.3 ibm-cos-sdk-s3transfer-2.14.3 ibm-watsonx-ai-1.4.11 idna-3.11 jmespath-1.0.1 jsonpatch-1.33 jsonpointer-3.0.0 langchain-core-0.3.80 langchain_ibm-0.3.20 langsmith-0.5.0 lomond-0.3.3 numpy-2.4.0 orjson-3.11.5 pandas-2.2.3 pydantic-2.12.5 pydantic-core-2.41.5 pytz-2025.2 requests-2.32.5 requests-toolbelt-1.0.0 tabulate-0.9.0 tenacity-9.1.2 typing-inspection-0.4.2 tzdata-2025.3 urllib3-2.6.2 uuid-utils-0.12.0 zstandard-0.25.0

# %% [markdown]
# #### Define credentials
#
# Authenticate the watsonx.ai Runtime service on IBM Cloud Pak® for Data. You need to provide the **admin's** `username` and the platform `url`.

# %%
username = "PASTE YOUR USERNAME HERE"
url = "PASTE THE PLATFORM URL HERE"

# %% [markdown]
# Use the **admin's** `api_key` to authenticate watsonx.ai Runtime services:

# %%
import getpass

from ibm_watsonx_ai import Credentials

credentials = Credentials(
    username=username,
    api_key=getpass.getpass("Enter your watsonx.ai API key and hit enter: "),
    url=url,
    instance_id="openshift",
    version="5.3",
)

# %% [markdown]
# Alternatively you can use the **admin's** `password`:

# %%
import getpass

from ibm_watsonx_ai import Credentials

if "credentials" not in locals() or not credentials.api_key:
    credentials = Credentials(
        username=username,
        password=getpass.getpass("Enter your watsonx.ai password and hit enter: "),
        url=url,
        instance_id="openshift",
        version="5.3",
    )

# %% [markdown]
# ### Working with projects
#
# First of all, you need to create a project that will be used for your work. If you do not have a project created already, follow the steps below:
#
# - Open IBM Cloud Pak® main page
# - Click all projects
# - Create an empty project
# - Copy `project_id` from url and paste it below
#
# **Action**: Assign project ID below

# %%
import os

try:
    project_id = os.environ["PROJECT_ID"]
except KeyError:
    project_id = input("Please enter your project_id (hit enter): ")

# %% [markdown]
# #### Create `APIClient` instance

# %%
from ibm_watsonx_ai import APIClient

client = APIClient(credentials, project_id=project_id)

# %% [markdown]
# <a id="models"></a>
# ## Set up the Foundation Model on `watsonx.ai`

# %% [markdown]
# #### Specify chat model
#
# This notebook uses chat model `ibm/granite-4-h-small`, which has to be available on your IBM Cloud Pak® for Data environment for this notebook to run successfully.
# If this model is not available on your IBM Cloud Pak® for Data environment, you can specify any other available chat model.
# You can list available chat models by running the cell below.

# %%
if len(client.foundation_models.ChatModels):
    print(*client.foundation_models.ChatModels, sep="\n")
else:
    print(
        "Chat models are missing in this environment. Install chat models to proceed."
    )
# Out:
# ibm/granite-3-8b-instruct
# ibm/granite-4-h-small

# %%
model_id = client.foundation_models.ChatModels.GRANITE_4_H_SMALL

# %% [markdown]
# ### Define the model parameters
#
# You might need to adjust model `parameters` depending on the model you use.

# %%
from ibm_watsonx_ai.foundation_models.schema import TextChatParameters

TextChatParameters.show()
# Out:
# +-----------------------+----------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | PARAMETER             | TYPE                                   | EXAMPLE VALUE                                                                                                                                                                                                                                                                   |
# +=======================+========================================+=================================================================================================================================================================================================================================================================================+
# | frequency_penalty     | float, NoneType                        | 0.5                                                                                                                                                                                                                                                                             |
# +-----------------------+----------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | logprobs              | bool, NoneType                         | True                                                                                                                                                                                                                                                                            |
# +-----------------------+----------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | top_logprobs          | int, NoneType                          | 3                                                                                                                                                                                                                                                                               |
# +-----------------------+----------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | presence_penalty      | float, NoneType                        | 0.3                                                                                                                                                                                                                                                                             |
# +-----------------------+----------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | response_format       | dict, TextChatResponseFormat, NoneType | {'type': 'json_schema', 'json_schema': {'name': 'Sample JSON schema', 'schema': {'title': 'SimpleUser', 'type': 'object', 'properties': {'username': {'type': 'string'}, 'email': {'type': 'string', 'format': 'email'}}, 'required': ['username', 'email']}, 'strict': False}} |
# +-----------------------+----------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | temperature           | float, NoneType                        | 0.7                                                                                                                                                                                                                                                                             |
# +-----------------------+----------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | max_tokens            | int, NoneType                          | N/A                                                                                                                                                                                                                                                                             |
# +-----------------------+----------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | max_completion_tokens | int, NoneType                          | 512                                                                                                                                                                                                                                                                             |
# +-----------------------+----------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | time_limit            | int, NoneType                          | 600000                                                                                                                                                                                                                                                                          |
# +-----------------------+----------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | top_p                 | float, NoneType                        | 0.9                                                                                                                                                                                                                                                                             |
# +-----------------------+----------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | n                     | int, NoneType                          | 1                                                                                                                                                                                                                                                                               |
# +-----------------------+----------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | logit_bias            | dict, NoneType                         | {'1003': -100, '1004': -100}                                                                                                                                                                                                                                                    |
# +-----------------------+----------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | seed                  | int, NoneType                          | 41                                                                                                                                                                                                                                                                              |
# +-----------------------+----------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | stop                  | list, NoneType                         | ['this', 'the']                                                                                                                                                                                                                                                                 |
# +-----------------------+----------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
params = TextChatParameters(temperature=1)

# %% [markdown]
# ### Initialize the model
#
# Initialize the `ModelInference` class with the previously set parameters.

# %%
from ibm_watsonx_ai.foundation_models import ModelInference

model = ModelInference(
    model_id=model_id, credentials=credentials, project_id=project_id, params=params
)

# %% [markdown]
# <a id="chat"></a>
# ## Work with chat messages

# %% [markdown]
# #### Work with a simple chat message

# %%
messages = [{"role": "user", "content": "What is 1 + 1"}]

simple_chat_response = model.chat(messages=messages)

# %%
print(simple_chat_response["choices"][0]["message"]["content"])
# Out:
# The answer to the mathematical problem 1 + 1 is 2. This is a basic arithmetic operation of addition.

# %% [markdown]
# #### Work with a simple chat message using chat_stream

# %%
messages = [{"role": "user", "content": "What IBM mainly does?"}]

simple_chat_stream_response = model.chat_stream(messages=messages)

# %%
for chunk in simple_chat_stream_response:
    if chunk["choices"]:
        print(chunk["choices"][0]["delta"].get("content", ""), end="", flush=True)
# Out:
# IBM, or International Business Machines Corporation, is a multinational technology company headquartered in Armonk, New York. IBM primarily provides infrastructure, software (including Red Hat), and consulting services in industries such as IT infrastructure, markets, and global services.
#
# Some of the main areas IBM operates in include:
#
# 1. Cloud Computing: IBM offers a robust cloud platform and a range of services, including AI and machine learning services, data analytics, and more.
#
# 2. Artificial Intelligence: IBM's Watson AI platform is used in various industries for tasks like predictive analytics, natural language processing, and machine learning.
#
# 3. Quantum Computing: IBM leads in quantum computing research and development, with their IBM Quantum Experience allowing anyone to run experiments on their quantum processors.
#
# 4. Blockchain: IBM works on providing enterprise blockchain solutions, with a focus on areas like supply chain management, trade finance, and the Internet of Things.
#
# 5. Consulting Services: IBM's Global Business Services unit provides IT consulting services and helps companies with digital transformation and technological innovation.
#
# 6. Software: IBM develops and manages infrastructure, middleware, and industry software, including the development of the Red Hat platform after its acquisition.
#
# 7. Hardware: While not as prominent as in the past, IBM still produces high-performance servers, mainframes, and other hardware.
#
# 8. Research and Development: IBM Research is one of the largest industrial research labs in the world, focusing on advancing technologies in areas like AI, quantum computing, cloud, blockchain, and more.
#
# Remember, the specifics of what IBM does can change over time due to factors like market trends, technological advancements, and strategic business decisions.

# %% [markdown]
# #### Work with an advanced chat message

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant."},
    {
        "role": "user",
        "content": [{"type": "text", "text": "Who won the world series in 2020?"}],
    },
    {
        "role": "assistant",
        "content": "The Los Angeles Dodgers won the World Series in 2020.",
    },
    {
        "role": "user",
        "content": [{"type": "text", "text": "Where was it played?"}],
    },
]

advanced_chat_response = model.chat(messages=messages)

# %%
print(advanced_chat_response["choices"][0]["message"]["content"])
# Out:
# The 2020 World Series was played at Globe Life Field in Arlington, Texas. Due to the COVID-19 pandemic, the series was moved from its traditional site at the home stadiums of the National League champion to a centralized location to minimize travel and potential exposure to the virus.

# %% [markdown]
# #### Work with chat messages using `tools` and `tool_choice`

# %%
def get_current_weather(location: str, unit: str = "celsius") -> dict:
    """
    Get the current weather in a given location.

    Parameters:
    - location (str): The city and state, e.g., "San Francisco, CA".
    - unit (str): The unit for temperature, either "celsius" or "fahrenheit". Defaults to "celsius".

    Returns:
    - dict: A dictionary containing the current weather details.
    """
    weather_data = {
        "location": location,
        "temperature": 20,
        "unit": unit,
        "description": "Partly cloudy",
    }
    return weather_data

# %% [markdown]
# Converting raw Python function to correct tool schema

# %%
import json

from langchain_ibm.chat_models import convert_to_openai_tool

formatted_tools = [convert_to_openai_tool(get_current_weather)]
print(json.dumps(formatted_tools, indent=4))
# Out:
# [
#     {
#         "type": "function",
#         "function": {
#             "name": "get_current_weather",
#             "description": "Get the current weather in a given location. Parameters:\n- location (str): The city and state, e.g., \"San Francisco, CA\".\n- unit (str): The unit for temperature, either \"celsius\" or \"fahrenheit\". Defaults to \"celsius\".",
#             "parameters": {
#                 "properties": {
#                     "location": {
#                         "type": "string"
#                     },
#                     "unit": {
#                         "default": "celsius",
#                         "type": "string"
#                     }
#                 },
#                 "required": [
#                     "location"
#                 ],
#                 "type": "object"
#             }
#         }
#     }
# ]

# %%
messages = [
    {"role": "user", "content": "What's the weather like in Boston today?"},
]

tool_choice = {"type": "function", "function": {"name": "get_current_weather"}}

tool_response = model.chat(
    messages=messages, tools=formatted_tools, tool_choice=tool_choice
)

# %%
print(json.dumps(tool_response["choices"][0]["message"], indent=4))
# Out:
# {
#     "role": "assistant",
#     "content": "",
#     "tool_calls": [
#         {
#             "id": "chatcmpl-tool-8218218ce8de4b4882b08511029ef575",
#             "type": "function",
#             "function": {
#                 "name": "get_current_weather",
#                 "arguments": "{\n  \"location\": \"Boston, MA\"\n}"
#             }
#         }
#     ]
# }

# %% [markdown]
# #### Work with chat messages using `tools` and `tool_choice_option`

# %%
def add_numbers(a: float, b: float) -> float:
    """
    Adds two numbers.

    Parameters:
    - a (float): The first number.
    - b (float): The second number.

    Returns:
    - float: The result of a + b.
    """
    return a + b


def multiply_numbers(a: float, b: float) -> float:
    """
    Multiplies two numbers.

    Parameters:
    - a (float): The first number.
    - b (float): The second number.

    Returns:
    - float: The result of a * b.
    """
    return a * b

# %% [markdown]
# Converting raw python function to correct tool schema

# %%
tool_choice_option = "auto"

formatted_tools = [
    convert_to_openai_tool(tool) for tool in [add_numbers, multiply_numbers]
]

print(json.dumps(formatted_tools, indent=4))
# Out:
# [
#     {
#         "type": "function",
#         "function": {
#             "name": "add_numbers",
#             "description": "Adds two numbers. Parameters:\n- a (float): The first number.\n- b (float): The second number.",
#             "parameters": {
#                 "properties": {
#                     "a": {
#                         "type": "number"
#                     },
#                     "b": {
#                         "type": "number"
#                     }
#                 },
#                 "required": [
#                     "a",
#                     "b"
#                 ],
#                 "type": "object"
#             }
#         }
#     },
#     {
#         "type": "function",
#         "function": {
#             "name": "multiply_numbers",
#             "description": "Multiplies two numbers. Parameters:\n- a (float): The first number.\n- b (float): The second number.",
#             "parameters": {
#                 "properties": {
#                     "a": {
#                         "type": "number"
#                     },
#                     "b": {
#                         "type": "number"
#                     }
#                 },
#                 "required": [
#                     "a",
#                     "b"
#                 ],
#                 "type": "object"
#             }
#         }
#     }
# ]

# %%
messages = [
    {"role": "user", "content": "What is 5 + 6?"},
]

tools_response = model.chat(
    messages=messages, tools=formatted_tools, tool_choice_option=tool_choice_option
)

print(json.dumps(tools_response["choices"][0]["message"], indent=4))
# Out:
# {
#     "role": "assistant",
#     "tool_calls": [
#         {
#             "id": "chatcmpl-tool-70cabd32c5864c6baa1fc1c30e501313",
#             "type": "function",
#             "function": {
#                 "name": "add_numbers",
#                 "arguments": "\"{\\n  \\\"a\\\": 5,\\n  \\\"b\\\": 6\\n}\""
#             }
#         }
#     ]
# }

# %%
messages = [
    {"role": "user", "content": "What is 5 * 6?"},
]

tools_response_2 = model.chat(
    messages=messages, tools=formatted_tools, tool_choice_option=tool_choice_option
)

print(json.dumps(tools_response_2["choices"][0]["message"], indent=4))
# Out:
# {
#     "role": "assistant",
#     "tool_calls": [
#         {
#             "id": "chatcmpl-tool-4c8d590eba534714acec2f741eada0a2",
#             "type": "function",
#             "function": {
#                 "name": "multiply_numbers",
#                 "arguments": "\"{\\n  \\\"a\\\": 5,\\n  \\\"b\\\": 6\\n}\""
#             }
#         }
#     ]
# }

# %% [markdown]
# #### Execute tool calls
#
# We organize the two functions into a dictionary where keys represent the function name, and values are the function.

# %%
names_to_functions = {
    "add_numbers": add_numbers,
    "multiply_numbers": multiply_numbers,
}

# %%
tool_call = tools_response["choices"][0]["message"]["tool_calls"]
function_name = tool_call[0]["function"]["name"]
function_params = json.loads(tool_call[0]["function"]["arguments"])
print(f"Executing function: `{function_name}`, with parameters: {function_params}")

if isinstance(function_params, str):
    function_params = json.loads(function_params)

function_result = names_to_functions[function_name](**function_params)
print(f"Function result: {function_result}")
# Out:
# Executing function: `add_numbers`, with parameters: {
#   "a": 5,
#   "b": 6
# }
# Function result: 11

# %%
tool_call = tools_response_2["choices"][0]["message"]["tool_calls"]
function_name = tool_call[0]["function"]["name"]
function_params = json.loads(tool_call[0]["function"]["arguments"])
print(f"Executing function: `{function_name}`, with parameters: {function_params}")

if isinstance(function_params, str):
    function_params = json.loads(function_params)

function_result = names_to_functions[function_name](**function_params)
print(f"Function result: {function_result}")
# Out:
# Executing function: `multiply_numbers`, with parameters: {
#   "a": 5,
#   "b": 6
# }
# Function result: 30

# %% [markdown]
# <a id="summary"></a>
# ## Summary and next steps
#
# You successfully completed this notebook!
#
# You learned how to work with chat models using tools and watsonx.ai.
#
# Check out our _<a href="https://ibm.github.io/watsonx-ai-python-sdk/samples.html" target="_blank" rel="noopener no referrer">Online Documentation</a>_ for more samples, tutorials, documentation, how-tos, and blog posts.

# %% [markdown]
# ### Author
#
# **Mateusz Szewczyk**, Software Engineer at watsonx.ai.

# %% [markdown]
# Copyright © 2024-2026 IBM. This notebook and its source code are released under the terms of the MIT License.
